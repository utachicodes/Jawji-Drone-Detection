# %% [markdown]
# # **Drone Detection Using YOLOv11x: A Comprehensive Approach**
#
# <br>
#
# <img src="https://images.pexels.com/photos/724921/pexels-photo-724921.jpeg" height=550 width=1000 alt="https://www.pexels.com/"/>
#
# <small>Picture Source: <a href="https://www.pexels.com/@pok-rie-33563/">Pok Rie</a></small>
#
# <br>
#
# ## **Abstract**
#
# Unmanned aerial vehicles (UAVs), or drones, have become integral to modern applications in areas such as surveillance, disaster response, precision agriculture, and logistics. However, their increasing presence poses significant security, safety, and privacy concerns, necessitating robust real-time detection systems. In this research, we present a drone detection framework powered by the YOLOv11x architecture—the most advanced iteration of the YOLO (You Only Look Once) family to date. By leveraging YOLOv11x’s enhanced feature extraction capabilities, optimized backbone, and sophisticated attention mechanisms, our model achieves superior detection performance for small, fast-moving aerial targets in complex environments.
#
# <br>
#
# ## **Introduction**
#
# The proliferation of drones has created both opportunities and risks. While beneficial in many sectors, unauthorized or malicious drone activities can threaten airspace safety, compromise privacy, and disrupt critical infrastructure. Detecting drones presents unique challenges: small object scale, rapid motion, and diverse visual appearances, especially under varying weather, lighting, and background conditions.
#
# <br>
#
# YOLO (You Only Look Once), introduced by Redmon et al. in 2015, transformed object detection by reframing it as a single-stage regression problem, enabling real-time inference with high accuracy. Since then, successive YOLO iterations have advanced in both efficiency and precision. YOLOv11, unveiled at YOLO Vision 2024, marks a significant architectural leap, incorporating the C3k2 block, Spatial Pyramid Pooling - Fast (SPPF), and the novel C2PSA (Convolutional block with Parallel Spatial Attention) module, delivering heightened detection accuracy without sacrificing computational efficiency [YOLOv11: An Overview of the Key Architectural Enhancements](https://arxiv.org/abs/2410.17725).
#
# <br>
#
# ## **Dataset**
#
# The model was trained and evaluated using the publicly available [YOLO Drone Detection Dataset](https://www.kaggle.com/datasets/muki2003/yolo-drone-detection-dataset), comprising thousands of annotated images captured across diverse environmental conditions, camera angles, and drone types. The dataset includes challenging scenarios such as drones partially occluded by buildings, flying against cluttered backgrounds, and operating in low-contrast conditions. This diversity enables robust model generalization across real-world scenarios.
#
# <br>
#
# ## **Methodology**
#
# We adopt the YOLOv11x architecture for its advanced backbone, efficient neck design, and multi-scale detection head. Key features include:
#
# * **C3k2 Blocks**: Parameter-efficient Cross Stage Partial bottlenecks with reduced kernel size for faster, more efficient feature extraction.
# * **SPPF**: Accelerated spatial pyramid pooling for multi-scale context aggregation.
# * **C2PSA Attention**: Spatial attention enhancement to improve detection of small, partially occluded targets.
# * **Optimized Neck**: Multi-scale feature fusion with attention-driven refinement for improved localization accuracy.
#
# Given the small size of drones relative to the scene, the attention mechanism in C2PSA significantly improves detection confidence in challenging conditions.
#
# <br>
#
# ## **Experimental Setup**
#
# Experiments were conducted on Google Colab Pro+ with NVIDIA A100 GPU acceleration. The YOLOv11x model was trained with the following hyperparameters:
#
# * **Image Size**: 640 px
# * **Batch Size**: 16
# * **Learning Rate**: 0.001
# * **Optimizer**: SGD with momentum
#
# Data augmentation included mosaic augmentation, random scaling, and color jitter to enhance model robustness. Training used early stopping to avoid overfitting, with evaluation metrics based on mAP50-95.
#
# <br>
#
# ## **Results and Discussion**
#
# The YOLOv11x-based detection system demonstrated high precision and recall, achieving superior performance over YOLOv8x in both speed and accuracy. Notably, the integration of C2PSA improved detection rates for drones at long distances and in cluttered urban environments.
#
# Compared to previous YOLO versions, YOLOv11x achieved approximately **54.5% mAP50-95** on the COCO benchmark at 13 ms latency (Khanam R.,  Hussain M., 2024), which translated into real-time performance for our UAV dataset.
#
# <br>
#
# ## **Keywords**
#
# * Drone Detection
# * YOLOv11x
# * Object Detection
# * Spatial Attention
# * Deep Learning
# * Real-Time Surveillance
#
# <br>
#
# Referene:
#
# Khanam, R., & Hussain, M. (2024). Yolov11: An overview of the key architectural enhancements. arXiv preprint arXiv:2410.17725.
#
# <br>
#
# Make sure your runtime is **GPU** (_not_ CPU or TPU). And if it is an option, make sure you are using _Python 3_. You can select these settings by going to `Runtime -> Change runtime type -> Select the above mentioned settings and then press SAVE`.

# %% [markdown]
# ## **1. Importing Libraries**

# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 81.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.4 MB/s eta 0:00:00

# %%
import os
from pathlib import Path
import pandas as pd
import cv2

from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
from PIL import Image

from google.colab import files
from google.colab import drive

import warnings
warnings.filterwarnings("ignore")

# %%
from ultralytics import YOLO, checks, solutions
import torch
checks()
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 43.1/112.6 GB disk)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
torch.__version__
# Out:
# '2.6.0+cu124'

# %% [markdown]
# ## **2. Data Preprocessing**
#
# To prepare the dataset for YOLOv11x training, a structured preprocessing pipeline was followed to ensure data integrity and optimal compatibility with the model.
#
# The dataset was split into two subsets:
#
# * **Training set**: 1,012 images with 1,012 corresponding YOLO-format annotation TXT files.
# * **Validation set**: 347 images with 348 annotation TXT files.
#
# Each annotation file used YOLO’s normalized format, containing the class ID and bounding box coordinates.

# %%
# !unzip -q /content/gdrive/MyDrive/archive.zip # <-- PLEASE CHECK DATA PATH

# %%
# files.upload()

# %%
#@markdown ---
#@markdown ### Enter image paths:
train_images_dir = "/content/drone_dataset/train/images" #@param {type:"string"}
val_images_dir = "/content/drone_dataset/valid/images" #@param {type:"string"}

train_image_count = len([f for f in os.listdir(train_images_dir) if f.endswith(".jpg")])
val_image_count = len([f for f in os.listdir(val_images_dir) if f.endswith(".jpg")])

print(f"Number of images in train folder: {train_image_count}")
print(f"Number of images in val folder: {val_image_count}")
# Out:
# Number of images in train folder: 1012
# Number of images in val folder: 347

# %%
#@markdown ---
#@markdown ### Enter label paths:
train_labels_dir = "/content/drone_dataset/train/labels" #@param {type:"string"}
val_labels_dir = "/content/drone_dataset/valid/labels" #@param {type:"string"}

train_txt_count = len([f for f in os.listdir(train_labels_dir) if f.endswith(".txt")])
val_txt_count = len([f for f in os.listdir(val_labels_dir) if f.endswith(".txt")])

print(f"Number of TXT files in train labels folder: {train_txt_count}")
print(f"Number of TXT files in val labels folder: {val_txt_count}")
# Out:
# Number of TXT files in train labels folder: 1012
# Number of TXT files in val labels folder: 348

# %% [markdown]
# ## **3. Training**
#
# Training was performed using the YOLOv11x architecture, chosen for its balance of high detection accuracy and real-time performance capabilities. The process involved configuring the dataset, initializing pre-trained weights, and fine-tuning the network parameters for the specific task of drone detection.
#
# A `data.yaml` configuration file was created to define dataset parameters:
#
# ```yaml
# train: ../drone_dataset/train
# val: ../drone_dataset/valid
#
# # number of classes
# nc: 1
#
# # class names
# names: ['drone']
# ```
#
# This YAML file informs YOLOv11x of the dataset structure, number of classes, and class names.

# %%
yaml_content = f'''
train: ../drone_dataset/train
val: ../drone_dataset/valid

# number of classes
nc: 1

# class names
names: ['drone']
    '''

with Path('data.yaml').open('w') as f:
    f.write(yaml_content)

# %% [markdown]
# **Parameter breakdown:**
#
# * **`train`**: Executes the YOLOv11x training pipeline.
# * **`model=yolov11x.pt`**: Uses pre-trained YOLOv11x weights as initialization.
# * **`data=/content/data.yaml`**: Specifies the dataset configuration file.
# * **`imgsz=640`**: Sets input resolution to enhance small-object detection.
# * **`lr0=0.001`**: Sets the learing rate for each training step.
# * **`epochs=32`**: Defines the number of training cycles over the dataset.
# * **`batch=16`**: Sets the batch size for each training step.
# * **`device=0`**: Allocates GPU device 0 for training.
# * **`optimizer=AdamW`**: As default, AdamW optimization algorithm utilized.
#
# By combining a robust preprocessing pipeline with the architectural strengths of YOLOv11x, the training process effectively adapted the model for the challenging task of drone detection, ensuring both speed and accuracy in real-world deployment scenarios.

# %%
model = YOLO("yolo11x.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x.pt to 'yolo11x.pt': 100%|██████████| 109M/109M [00:01<00:00, 99.1MB/s]

# %% [markdown]
# During training, all images were resized to **640×640 pixels** with letterboxing to preserve aspect ratios. Data augmentation techniques—mosaic augmentation, random scaling, and HSV color jitter—were applied to improve the model's generalization capabilities, particularly in varied environmental conditions.
#
# The YOLOv11x training command was:

# %%
results = model.train(
        batch=16,
        data="data.yaml",
        epochs=32,
        imgsz=640,
        lr0=0.001,
        optimizer='AdamW'
    )
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=32, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11x.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100%|██████████| 755k/755k [00:00<00:00, 63.7MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  2   5022720  ultralytics.nn.modules.block.C3k2            [768, 768, 2, True]
#   9                  -1  1   1476864  ultralytics.nn.modules.block.SPPF            [768, 768, 5]
#  10                  -1  2   3264768  ultralytics.nn.modules.block.C2PSA           [768, 768, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2   1700352  ultralytics.nn.modules.block.C3k2            [1536, 384, 2, True]
#  17                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   5317632  ultralytics.nn.modules.block.C3k2            [1152, 768, 2, True]
#  20                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  23        [16, 19, 22]  1   3146707  ultralytics.nn.modules.head.Detect           [1, [384, 768, 768]]
# YOLO11x summary: 357 layers, 56,874,931 parameters, 56,874,915 gradients, 195.4 GFLOPs
#
# Transferred 1009/1015 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100%|██████████| 5.35M/5.35M [00:00<00:00, 152MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2114.6±1759.8 MB/s, size: 804.8 KB)
# train: Scanning /content/drone_dataset/train/labels... 1012 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1012/1012 [00:01<00:00, 654.35it/s]
# train: /content/drone_dataset/train/images/pic_722.jpg: corrupt JPEG restored and saved
# train: New cache created: /content/drone_dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 841.4±503.7 MB/s, size: 339.9 KB)
# val: Scanning /content/drone_dataset/valid/labels... 347 images, 0 backgrounds, 0 corrupt: 100%|██████████| 347/347 [00:00<00:00, 643.36it/s]
# val: New cache created: /content/drone_dataset/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.0005), 173 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 32 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/32      14.9G      1.618      2.018      1.871         12        640: 100%|██████████| 64/64 [00:47<00:00,  1.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:05<00:00,  2.12it/s]
#                    all        347        369      0.198      0.366      0.139     0.0348
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/32      15.6G        1.7      1.624       1.89          9        640: 100%|██████████| 64/64 [00:45<00:00,  1.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
#                    all        347        369   0.000692      0.176   0.000407   0.000149
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/32      15.7G      1.718      1.652      1.851         10        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.57it/s]
#                    all        347        369      0.137     0.0759     0.0416     0.0139
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/32      15.8G      1.655       1.57       1.81         10        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.53it/s]
#                    all        347        369      0.324      0.125      0.106     0.0398
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/32      15.8G      1.581      1.489      1.749         10        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.52it/s]
#                    all        347        369      0.281      0.363      0.222     0.0774
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/32      15.8G      1.548      1.402      1.699         11        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.52it/s]
#                    all        347        369      0.583      0.472      0.476      0.209
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/32      15.8G       1.55      1.374      1.709          7        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
#                    all        347        369      0.765      0.545      0.611      0.301
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/32      15.8G      1.492       1.34      1.648          9        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.53it/s]
#                    all        347        369      0.792      0.629      0.718      0.372
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/32      15.8G      1.426      1.248      1.617         10        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.55it/s]
#                    all        347        369      0.753       0.67      0.681      0.339
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/32      15.8G      1.458      1.282      1.633         12        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
#                    all        347        369      0.717      0.619      0.664      0.339
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/32      15.8G      1.362       1.15      1.564         10        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
#                    all        347        369      0.781      0.639      0.719      0.382
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/32      15.8G       1.38      1.147      1.575         10        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.56it/s]
#                    all        347        369       0.76      0.528      0.603       0.28
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/32      15.8G      1.352      1.109      1.555         10        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.56it/s]
#                    all        347        369      0.783      0.706      0.767      0.449
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/32      15.8G      1.327      1.037      1.533         15        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.55it/s]
#                    all        347        369      0.831      0.709      0.757      0.409
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/32      15.8G      1.318      1.061      1.504         14        640: 100%|██████████| 64/64 [00:45<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.55it/s]
#                    all        347        369      0.841      0.696      0.785      0.454
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/32      15.8G      1.309      1.023      1.499         12        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
#                    all        347        369      0.786      0.675      0.725      0.431
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/32      15.8G      1.297      1.019      1.502         12        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.55it/s]
#                    all        347        369      0.812      0.759      0.816      0.463
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/32      15.8G      1.276     0.9665      1.479          7        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.55it/s]
#                    all        347        369      0.724      0.745      0.743      0.365
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/32      15.8G      1.243       0.96      1.461         11        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
#                    all        347        369      0.853      0.762      0.831      0.482
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/32      15.8G      1.231      0.933      1.466         11        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.53it/s]
#                    all        347        369      0.891      0.775      0.859      0.496
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/32      15.8G      1.229     0.9316      1.443         15        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
#                    all        347        369      0.828      0.794      0.835      0.448
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/32      15.8G      1.207     0.8916      1.427         11        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.53it/s]
#                    all        347        369      0.835      0.772      0.837      0.457
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/32      15.8G      1.123     0.7665      1.463          4        640: 100%|██████████| 64/64 [00:46<00:00,  1.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
#                    all        347        369      0.875      0.759      0.858      0.502
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/32      15.8G      1.087     0.6995      1.427          4        640: 100%|██████████| 64/64 [00:45<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.55it/s]
#                    all        347        369      0.823      0.783      0.822      0.461
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/32      15.8G      1.068     0.6746      1.428          4        640: 100%|██████████| 64/64 [00:45<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.55it/s]
#                    all        347        369      0.791      0.751      0.821      0.478
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/32      15.8G      1.074     0.6756       1.42          4        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
#                    all        347        369      0.818      0.744      0.829      0.487
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/32      15.8G      1.032     0.6337      1.394          4        640: 100%|██████████| 64/64 [00:45<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.56it/s]
#                    all        347        369      0.911      0.803       0.89       0.51
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/32      15.8G      1.006     0.6108      1.372          4        640: 100%|██████████| 64/64 [00:45<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.55it/s]
#                    all        347        369      0.886      0.848      0.914      0.521
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/32      15.8G     0.9853     0.5745      1.342          4        640: 100%|██████████| 64/64 [00:45<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
#                    all        347        369       0.87      0.846      0.896      0.509
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/32      15.8G     0.9365     0.5537      1.311          4        640: 100%|██████████| 64/64 [00:45<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.55it/s]
#                    all        347        369      0.891      0.832      0.899      0.542
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/32      15.8G     0.9483      0.551      1.312          4        640: 100%|██████████| 64/64 [00:45<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.56it/s]
#                    all        347        369      0.919       0.83      0.905      0.546
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/32      15.8G      0.924     0.5323      1.324          4        640: 100%|██████████| 64/64 [00:45<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.56it/s]
#                    all        347        369      0.887      0.869       0.91      0.527
# 32 epochs completed in 0.459 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 114.4MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 114.4MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# YOLO11x summary (fused): 190 layers, 56,828,179 parameters, 0 gradients, 194.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:04<00:00,  2.50it/s]
#                    all        347        369      0.922      0.831      0.905      0.546
# Speed: 0.1ms preprocess, 8.9ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train

# %%
image = mpimg.imread('/content/runs/detect/train/results.png')
plt.figure(figsize=(16, 9), dpi=300)
plt.title('Results')
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# To calculate *mAP @ 0.5*, the model's predicted bounding boxes are compared to the ground truth bounding boxes for various objects in the dataset. The average precision (AP) is computed for each class at an IoU threshold of 0.5, and then the mean of these average precision scores is calculated across all classes. *mAP @ 0.5* provides an overall measure of the model's detection performance, indicating how well it can identify objects with a reasonable overlap threshold.

# %% [markdown]
# ## **4. Inference and Visualization**

# %% [markdown]
# After training, the optimal model weights located at `/content/runs/detect/train/weights/best.pt` were used for real-time inference and drone tracking. This phase validated the YOLOv11x model’s ability to detect and track drones within video streams.
#
# The model was loaded and applied to a test video using:
#
# **Explanation:**
#
# * **`model.track`**: Runs the detection and tracking pipeline.
# * **`conf=0.3`**: Filters detections below 30% confidence.
# * **`iou=0.5`**: Sets the IoU threshold for Non-Maximum Suppression.
# * **`show=True`**: Displays the video feed with tracking annotations.

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
result = model.track(
    source="/content/pexels-joseph-redfield-8459631 (1080p).mp4",
    conf=0.3,
    iou=0.5,
    show=False,
    imgsz=640,
    save=True,
    project="my_outputs",
    name="tracking_output",
    exist_ok=True  # overwrite if folder exists
)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.1ms
# video 1/1 (frame 2/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 3/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 4/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 5/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 6/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 7/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 8/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 9/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 10/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 11/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 12/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 13/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 14/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.0ms
# video 1/1 (frame 15/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 16/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 17/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 18/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 19/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 20/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 2 drones, 21.2ms
# video 1/1 (frame 21/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 22/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 23/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 24/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 25/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 26/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 27/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.3ms
# video 1/1 (frame 28/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 29/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 30/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 31/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 32/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 33/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 34/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 35/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 36/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 37/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 38/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 39/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.0ms
# video 1/1 (frame 40/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 41/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 42/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 43/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 44/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 45/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 46/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 47/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 48/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.0ms
# video 1/1 (frame 49/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 50/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 51/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 52/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.1ms
# video 1/1 (frame 53/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 54/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 55/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 56/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.0ms
# video 1/1 (frame 57/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 58/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.1ms
# video 1/1 (frame 59/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.7ms
# video 1/1 (frame 60/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 61/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 62/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 63/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 64/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.3ms
# video 1/1 (frame 65/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 66/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 24.1ms
# video 1/1 (frame 67/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 68/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.5ms
# video 1/1 (frame 69/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 70/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 71/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 72/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 73/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.5ms
# video 1/1 (frame 74/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 75/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 24.5ms
# video 1/1 (frame 76/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.6ms
# video 1/1 (frame 77/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 78/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 79/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.7ms
# video 1/1 (frame 80/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 81/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 82/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.2ms
# video 1/1 (frame 83/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 84/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 85/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.0ms
# video 1/1 (frame 86/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 87/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 88/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.5ms
# video 1/1 (frame 89/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 90/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 91/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 92/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 93/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 94/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 95/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 96/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.2ms
# video 1/1 (frame 97/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 98/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.1ms
# video 1/1 (frame 99/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 100/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.9ms
# video 1/1 (frame 101/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 102/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 103/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 104/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 105/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 106/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 107/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 108/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.2ms
# video 1/1 (frame 109/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 110/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 111/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 112/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 113/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 114/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 115/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 116/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 117/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 118/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 119/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 120/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 121/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.0ms
# video 1/1 (frame 122/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 123/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 124/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 125/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 126/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 127/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 128/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 129/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 130/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 131/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 25.6ms
# video 1/1 (frame 132/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 133/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 134/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 135/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 136/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 137/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 138/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 139/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 140/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 141/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 142/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 143/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 144/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 145/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 146/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 147/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 148/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 149/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 150/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 151/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 152/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 153/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 154/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 155/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 156/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 157/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 158/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 159/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 160/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 161/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 162/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 163/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 164/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 165/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 166/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 167/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 168/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 169/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 170/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.0ms
# video 1/1 (frame 171/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 172/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 173/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 174/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 175/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 176/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 177/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 178/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.0ms
# video 1/1 (frame 179/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 180/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 181/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 182/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 183/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 184/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 185/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 186/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 187/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 188/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 189/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.2ms
# video 1/1 (frame 190/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 191/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 192/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 193/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 194/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 195/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 196/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 197/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 198/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 199/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 27.9ms
# video 1/1 (frame 200/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 201/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 202/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 203/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 204/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 205/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 206/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 207/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.4ms
# video 1/1 (frame 208/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 209/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.8ms
# video 1/1 (frame 210/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 211/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.9ms
# video 1/1 (frame 212/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 213/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 214/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 215/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 216/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 217/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 218/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.9ms
# video 1/1 (frame 219/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 24.8ms
# video 1/1 (frame 220/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 221/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.9ms
# video 1/1 (frame 222/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.7ms
# video 1/1 (frame 223/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.9ms
# video 1/1 (frame 224/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 225/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.3ms
# video 1/1 (frame 226/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 227/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 228/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 229/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.9ms
# video 1/1 (frame 230/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 231/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.9ms
# video 1/1 (frame 232/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 233/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 24.4ms
# video 1/1 (frame 234/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 235/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.6ms
# video 1/1 (frame 236/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.6ms
# video 1/1 (frame 237/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 238/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 239/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 240/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 241/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 242/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 243/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 24.5ms
# video 1/1 (frame 244/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 245/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 246/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.3ms
# video 1/1 (frame 247/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.4ms
# video 1/1 (frame 248/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 249/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.3ms
# video 1/1 (frame 250/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.6ms
# video 1/1 (frame 251/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 252/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 253/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.1ms
# video 1/1 (frame 254/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 255/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 24.8ms
# video 1/1 (frame 256/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 257/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 258/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 259/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.9ms
# video 1/1 (frame 260/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.1ms
# video 1/1 (frame 261/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 262/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 263/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.2ms
# video 1/1 (frame 264/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.8ms
# video 1/1 (frame 265/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 266/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 267/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 25.3ms
# video 1/1 (frame 268/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 269/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 2 drones, 20.8ms
# video 1/1 (frame 270/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 2 drones, 20.7ms
# video 1/1 (frame 271/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 2 drones, 20.8ms
# video 1/1 (frame 272/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 2 drones, 20.9ms
# video 1/1 (frame 273/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 2 drones, 20.4ms
# video 1/1 (frame 274/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 2 drones, 20.4ms
# video 1/1 (frame 275/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 276/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 277/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 278/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 279/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.5ms
# video 1/1 (frame 280/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.0ms
# video 1/1 (frame 281/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.4ms
# video 1/1 (frame 282/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 283/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 284/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 285/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 286/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 287/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 288/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 289/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 290/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 291/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 292/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 293/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 294/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 295/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.8ms
# video 1/1 (frame 296/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.4ms
# video 1/1 (frame 297/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 298/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 2 drones, 20.1ms
# video 1/1 (frame 299/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 2 drones, 20.1ms
# video 1/1 (frame 300/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 301/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.8ms
# video 1/1 (frame 302/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.7ms
# video 1/1 (frame 303/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.8ms
# video 1/1 (frame 304/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 305/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 306/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 307/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 308/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 309/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 310/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 311/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 312/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 313/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 314/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 315/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 316/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 317/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 318/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 319/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 320/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 321/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 322/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 323/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 324/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 325/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 326/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 327/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.0ms
# video 1/1 (frame 328/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 329/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 330/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 331/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 332/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 333/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 334/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 335/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 336/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 337/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 338/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 339/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 340/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 341/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 342/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 343/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 344/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 345/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 346/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 347/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 348/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.9ms
# video 1/1 (frame 349/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.0ms
# video 1/1 (frame 350/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 351/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 352/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 353/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 354/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 355/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 356/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 357/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 358/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 359/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 360/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 361/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 362/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 363/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.9ms
# video 1/1 (frame 364/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 365/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 366/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 367/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 368/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 369/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 370/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 371/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 372/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 373/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 374/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 375/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 376/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 377/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 378/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 379/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 380/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 381/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 382/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 383/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 384/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 385/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 386/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 387/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 388/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 389/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 390/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 391/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 392/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 393/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.3ms
# video 1/1 (frame 394/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 395/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 396/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 397/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 398/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 399/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 400/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 401/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 402/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 403/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 404/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 405/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 406/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 407/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.6ms
# video 1/1 (frame 408/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 409/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 410/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 411/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 412/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 413/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 414/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 415/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 416/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 417/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 418/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.4ms
# video 1/1 (frame 419/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 420/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 21.1ms
# video 1/1 (frame 421/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 422/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 423/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 424/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 425/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 426/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 427/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 428/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 429/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 430/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 431/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 432/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 433/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.9ms
# video 1/1 (frame 434/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 435/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.5ms
# video 1/1 (frame 436/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 437/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 438/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 439/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 440/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 441/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 442/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 443/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 444/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 445/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 446/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 447/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 448/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 449/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 450/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 451/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 452/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 453/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 454/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.8ms
# video 1/1 (frame 455/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 456/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.8ms
# video 1/1 (frame 457/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 458/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 459/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 460/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 461/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 462/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 463/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 464/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 465/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 466/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 467/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 468/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.8ms
# video 1/1 (frame 469/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 470/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 471/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 472/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 473/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 474/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.8ms
# video 1/1 (frame 475/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 476/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 477/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 478/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 479/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 480/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 481/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 482/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 483/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 484/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.9ms
# video 1/1 (frame 485/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.9ms
# video 1/1 (frame 486/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 19.8ms
# video 1/1 (frame 487/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 488/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 489/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 490/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 491/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 492/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 493/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 494/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 495/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 496/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 497/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 498/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 499/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 500/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 501/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 502/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 503/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 504/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 505/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 506/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 507/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 508/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 509/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 510/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 511/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 512/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 513/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 514/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 515/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 516/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 517/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.8ms
# video 1/1 (frame 518/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 519/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 520/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.0ms
# video 1/1 (frame 521/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 522/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 523/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.3ms
# video 1/1 (frame 524/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 525/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 526/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.0ms
# video 1/1 (frame 527/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.8ms
# video 1/1 (frame 528/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 529/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.7ms
# video 1/1 (frame 530/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 531/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.6ms
# video 1/1 (frame 532/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 22.9ms
# video 1/1 (frame 533/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 534/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 535/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.1ms
# video 1/1 (frame 536/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 537/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 538/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 23.0ms
# video 1/1 (frame 539/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 540/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.7ms
# video 1/1 (frame 541/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 542/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 543/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.1ms
# video 1/1 (frame 544/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 545/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 546/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.4ms
# video 1/1 (frame 547/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.5ms
# video 1/1 (frame 548/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 549/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.0ms
# video 1/1 (frame 550/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.2ms
# video 1/1 (frame 551/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.3ms
# video 1/1 (frame 552/552) /content/pexels-joseph-redfield-8459631 (1080p).mp4: 384x640 1 drone, 20.9ms
# Speed: 2.3ms preprocess, 20.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to my_outputs/tracking_output

# %% [markdown]
# In addition to tracking, a heatmap visualization was implemented to identify regions with higher drone activity. This was done using OpenCV and a YOLO-based heatmap solution:

# %%
import numpy as np

# %%
cap = cv2.VideoCapture("/content/pexels-joseph-redfield-8459631 (1080p).mp4")

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter("/content/my_outputs/tracking_output/heatmap_output.mp4", fourcc, fps, (width, height))

heatmap = solutions.Heatmap(
    colormap=cv2.COLORMAP_JET,
    show=False,
    model="/content/runs/detect/train/weights/best.pt"
)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        break

    results = heatmap(im0)
    processed_img = results.plot_im

    processed_img_bgr = cv2.cvtColor(processed_img, cv2.COLOR_RGB2BGR)

    out.write(processed_img_bgr)

cap.release()
out.release()
cv2.destroyAllWindows()

print("Video processing complete. Saved to /content/my_outputs/tracking_output/heatmap_output.mp4")
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': '/content/runs/detect/train/weights/best.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': None, 'colormap': 2, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': False, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# 0: 1080x1920 31.8ms, 1 drone
# Speed: 738.6ms track, 31.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 1: 1080x1920 24.1ms, 1 drone
# Speed: 49.3ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 2: 1080x1920 23.3ms, 1 drone
# Speed: 50.6ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 3: 1080x1920 24.2ms, 1 drone
# Speed: 49.9ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 4: 1080x1920 23.8ms, 1 drone
# Speed: 49.5ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 5: 1080x1920 24.1ms, 1 drone
# Speed: 50.1ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 6: 1080x1920 24.2ms, 1 drone
# Speed: 48.8ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 7: 1080x1920 24.4ms, 1 drone
# Speed: 49.5ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 8: 1080x1920 24.4ms, 1 drone
# Speed: 53.7ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 9: 1080x1920 24.5ms, 1 drone
# Speed: 49.3ms track, 24.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 10: 1080x1920 24.6ms, 1 drone
# Speed: 50.9ms track, 24.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 11: 1080x1920 24.7ms, 1 drone
# Speed: 50.0ms track, 24.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 12: 1080x1920 25.2ms, 1 drone
# Speed: 48.5ms track, 25.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 13: 1080x1920 24.6ms, 1 drone
# Speed: 50.3ms track, 24.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 14: 1080x1920 24.8ms, 1 drone
# Speed: 48.2ms track, 24.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 15: 1080x1920 24.4ms, 1 drone
# Speed: 49.4ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 16: 1080x1920 24.4ms, 1 drone
# Speed: 49.1ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 17: 1080x1920 24.2ms, 1 drone
# Speed: 49.1ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 18: 1080x1920 72.9ms, 2 drone
# Speed: 48.8ms track, 72.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 19: 1080x1920 71.9ms, 2 drone
# Speed: 50.4ms track, 71.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 20: 1080x1920 28.7ms, 1 drone
# Speed: 57.8ms track, 28.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 21: 1080x1920 24.6ms, 1 drone
# Speed: 51.7ms track, 24.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 22: 1080x1920 24.0ms, 1 drone
# Speed: 48.9ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 23: 1080x1920 24.6ms, 1 drone
# Speed: 48.4ms track, 24.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 24: 1080x1920 69.7ms, 2 drone
# Speed: 49.7ms track, 69.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 25: 1080x1920 24.6ms, 1 drone
# Speed: 48.5ms track, 24.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 26: 1080x1920 24.1ms, 1 drone
# Speed: 49.1ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 27: 1080x1920 24.2ms, 1 drone
# Speed: 50.1ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 28: 1080x1920 24.0ms, 1 drone
# Speed: 48.6ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 29: 1080x1920 23.7ms, 1 drone
# Speed: 48.0ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 30: 1080x1920 23.6ms, 1 drone
# Speed: 48.2ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 31: 1080x1920 23.5ms, 1 drone
# Speed: 50.5ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 32: 1080x1920 23.4ms, 1 drone
# Speed: 53.1ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 33: 1080x1920 23.3ms, 1 drone
# Speed: 48.4ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 34: 1080x1920 23.5ms, 1 drone
# Speed: 47.5ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 35: 1080x1920 23.4ms, 1 drone
# Speed: 48.3ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 36: 1080x1920 23.5ms, 1 drone
# Speed: 48.6ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 37: 1080x1920 23.6ms, 1 drone
# Speed: 48.1ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 38: 1080x1920 23.2ms, 1 drone
# Speed: 48.1ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 39: 1080x1920 23.6ms, 1 drone
# Speed: 47.3ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 40: 1080x1920 23.2ms, 1 drone
# Speed: 47.9ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 41: 1080x1920 23.4ms, 1 drone
# Speed: 49.8ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 42: 1080x1920 26.4ms, 1 drone
# Speed: 48.7ms track, 26.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 43: 1080x1920 24.4ms, 1 drone
# Speed: 48.9ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 44: 1080x1920 25.1ms, 1 drone
# Speed: 55.4ms track, 25.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 45: 1080x1920 25.8ms, 1 drone
# Speed: 51.5ms track, 25.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 46: 1080x1920 24.6ms, 1 drone
# Speed: 50.0ms track, 24.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 47: 1080x1920 24.7ms, 1 drone
# Speed: 49.3ms track, 24.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 48: 1080x1920 25.1ms, 1 drone
# Speed: 50.3ms track, 25.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 49: 1080x1920 24.8ms, 1 drone
# Speed: 51.2ms track, 24.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 50: 1080x1920 24.1ms, 1 drone
# Speed: 50.5ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 51: 1080x1920 24.2ms, 1 drone
# Speed: 49.9ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 52: 1080x1920 23.9ms, 1 drone
# Speed: 50.3ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 53: 1080x1920 23.6ms, 1 drone
# Speed: 48.5ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 54: 1080x1920 23.7ms, 1 drone
# Speed: 48.6ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 55: 1080x1920 24.2ms, 1 drone
# Speed: 48.9ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 56: 1080x1920 24.5ms, 1 drone
# Speed: 54.1ms track, 24.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 57: 1080x1920 24.3ms, 1 drone
# Speed: 49.4ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 58: 1080x1920 24.9ms, 1 drone
# Speed: 48.9ms track, 24.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 59: 1080x1920 24.6ms, 1 drone
# Speed: 49.9ms track, 24.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 60: 1080x1920 24.0ms, 1 drone
# Speed: 51.2ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 61: 1080x1920 24.3ms, 1 drone
# Speed: 50.1ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 62: 1080x1920 24.3ms, 1 drone
# Speed: 48.8ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 63: 1080x1920 23.8ms, 1 drone
# Speed: 49.7ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 64: 1080x1920 23.4ms, 1 drone
# Speed: 48.4ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 65: 1080x1920 23.3ms, 1 drone
# Speed: 48.6ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 66: 1080x1920 23.0ms, 1 drone
# Speed: 48.5ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 67: 1080x1920 23.1ms, 1 drone
# Speed: 49.8ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 68: 1080x1920 23.2ms, 1 drone
# Speed: 53.9ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 69: 1080x1920 23.5ms, 1 drone
# Speed: 48.8ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 70: 1080x1920 23.4ms, 1 drone
# Speed: 49.8ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 71: 1080x1920 23.3ms, 1 drone
# Speed: 49.6ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 72: 1080x1920 24.1ms, 1 drone
# Speed: 48.6ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 73: 1080x1920 23.4ms, 1 drone
# Speed: 48.7ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 74: 1080x1920 23.4ms, 1 drone
# Speed: 50.3ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 75: 1080x1920 23.3ms, 1 drone
# Speed: 50.6ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 76: 1080x1920 23.8ms, 1 drone
# Speed: 50.1ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 77: 1080x1920 24.1ms, 1 drone
# Speed: 48.8ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 78: 1080x1920 23.9ms, 1 drone
# Speed: 50.2ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 79: 1080x1920 24.2ms, 1 drone
# Speed: 48.8ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 80: 1080x1920 24.2ms, 1 drone
# Speed: 54.5ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 81: 1080x1920 23.6ms, 1 drone
# Speed: 50.1ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 82: 1080x1920 23.8ms, 1 drone
# Speed: 51.3ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 83: 1080x1920 23.6ms, 1 drone
# Speed: 52.4ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 84: 1080x1920 23.6ms, 1 drone
# Speed: 49.2ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 85: 1080x1920 24.1ms, 1 drone
# Speed: 50.4ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 86: 1080x1920 23.9ms, 1 drone
# Speed: 48.9ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 87: 1080x1920 24.1ms, 1 drone
# Speed: 49.3ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 88: 1080x1920 24.0ms, 1 drone
# Speed: 49.9ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 89: 1080x1920 23.6ms, 1 drone
# Speed: 49.6ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 90: 1080x1920 23.3ms, 1 drone
# Speed: 48.5ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 91: 1080x1920 22.8ms, 1 drone
# Speed: 50.1ms track, 22.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 92: 1080x1920 23.3ms, 1 drone
# Speed: 49.8ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 93: 1080x1920 23.4ms, 1 drone
# Speed: 50.0ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 94: 1080x1920 23.6ms, 1 drone
# Speed: 49.4ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 95: 1080x1920 23.4ms, 1 drone
# Speed: 52.0ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 96: 1080x1920 23.2ms, 1 drone
# Speed: 49.4ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 97: 1080x1920 23.8ms, 1 drone
# Speed: 49.2ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 98: 1080x1920 23.7ms, 1 drone
# Speed: 49.1ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 99: 1080x1920 23.6ms, 1 drone
# Speed: 50.2ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 100: 1080x1920 23.8ms, 1 drone
# Speed: 48.2ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 101: 1080x1920 23.9ms, 1 drone
# Speed: 50.5ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 102: 1080x1920 24.2ms, 1 drone
# Speed: 50.9ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 103: 1080x1920 23.9ms, 1 drone
# Speed: 50.1ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 104: 1080x1920 23.7ms, 1 drone
# Speed: 49.6ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 105: 1080x1920 23.8ms, 1 drone
# Speed: 48.0ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 106: 1080x1920 23.6ms, 1 drone
# Speed: 48.7ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 107: 1080x1920 23.7ms, 1 drone
# Speed: 48.6ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 108: 1080x1920 23.5ms, 1 drone
# Speed: 48.5ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 109: 1080x1920 23.4ms, 1 drone
# Speed: 49.7ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 110: 1080x1920 23.7ms, 1 drone
# Speed: 49.8ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 111: 1080x1920 23.1ms, 1 drone
# Speed: 49.4ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 112: 1080x1920 23.7ms, 1 drone
# Speed: 48.5ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 113: 1080x1920 23.2ms, 1 drone
# Speed: 48.6ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 114: 1080x1920 23.6ms, 1 drone
# Speed: 48.6ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 115: 1080x1920 22.9ms, 1 drone
# Speed: 48.2ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 116: 1080x1920 23.7ms, 1 drone
# Speed: 50.7ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 117: 1080x1920 23.8ms, 1 drone
# Speed: 49.6ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 118: 1080x1920 22.9ms, 1 drone
# Speed: 50.2ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 119: 1080x1920 23.6ms, 1 drone
# Speed: 54.5ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 120: 1080x1920 23.6ms, 1 drone
# Speed: 47.9ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 121: 1080x1920 24.2ms, 1 drone
# Speed: 49.1ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 122: 1080x1920 23.7ms, 1 drone
# Speed: 49.8ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 123: 1080x1920 23.8ms, 1 drone
# Speed: 50.2ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 124: 1080x1920 23.7ms, 1 drone
# Speed: 53.3ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 125: 1080x1920 23.4ms, 1 drone
# Speed: 48.9ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 126: 1080x1920 23.9ms, 1 drone
# Speed: 49.0ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 127: 1080x1920 23.9ms, 1 drone
# Speed: 52.5ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 128: 1080x1920 23.1ms, 1 drone
# Speed: 51.7ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 129: 1080x1920 23.5ms, 1 drone
# Speed: 50.1ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 130: 1080x1920 24.4ms, 1 drone
# Speed: 49.6ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 131: 1080x1920 24.9ms, 1 drone
# Speed: 51.8ms track, 24.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 132: 1080x1920 25.7ms, 1 drone
# Speed: 57.0ms track, 25.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 133: 1080x1920 24.2ms, 1 drone
# Speed: 53.3ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 134: 1080x1920 23.9ms, 1 drone
# Speed: 50.1ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 135: 1080x1920 24.1ms, 1 drone
# Speed: 50.0ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 136: 1080x1920 22.9ms, 1 drone
# Speed: 49.6ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 137: 1080x1920 23.9ms, 1 drone
# Speed: 49.0ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 138: 1080x1920 23.3ms, 1 drone
# Speed: 47.7ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 139: 1080x1920 23.8ms, 1 drone
# Speed: 48.0ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 140: 1080x1920 23.6ms, 1 drone
# Speed: 49.4ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 141: 1080x1920 23.4ms, 1 drone
# Speed: 49.5ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 142: 1080x1920 23.7ms, 1 drone
# Speed: 52.2ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 143: 1080x1920 23.9ms, 1 drone
# Speed: 48.7ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 144: 1080x1920 23.9ms, 1 drone
# Speed: 49.2ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 145: 1080x1920 24.3ms, 1 drone
# Speed: 51.4ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 146: 1080x1920 23.6ms, 1 drone
# Speed: 48.3ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 147: 1080x1920 24.2ms, 1 drone
# Speed: 47.6ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 148: 1080x1920 24.0ms, 1 drone
# Speed: 47.9ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 149: 1080x1920 24.6ms, 1 drone
# Speed: 47.9ms track, 24.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 150: 1080x1920 24.7ms, 1 drone
# Speed: 47.6ms track, 24.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 151: 1080x1920 23.8ms, 1 drone
# Speed: 49.6ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 152: 1080x1920 23.9ms, 1 drone
# Speed: 48.8ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 153: 1080x1920 24.3ms, 1 drone
# Speed: 47.3ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 154: 1080x1920 24.8ms, 1 drone
# Speed: 52.8ms track, 24.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 155: 1080x1920 24.3ms, 1 drone
# Speed: 48.6ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 156: 1080x1920 24.0ms, 1 drone
# Speed: 47.5ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 157: 1080x1920 23.4ms, 1 drone
# Speed: 51.9ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 158: 1080x1920 23.8ms, 1 drone
# Speed: 47.9ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 159: 1080x1920 24.1ms, 1 drone
# Speed: 49.3ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 160: 1080x1920 24.2ms, 1 drone
# Speed: 53.3ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 161: 1080x1920 23.8ms, 1 drone
# Speed: 49.2ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 162: 1080x1920 24.1ms, 1 drone
# Speed: 48.0ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 163: 1080x1920 23.8ms, 1 drone
# Speed: 49.2ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 164: 1080x1920 23.7ms, 1 drone
# Speed: 50.4ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 165: 1080x1920 23.5ms, 1 drone
# Speed: 47.3ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 166: 1080x1920 23.5ms, 1 drone
# Speed: 52.1ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 167: 1080x1920 23.7ms, 1 drone
# Speed: 47.7ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 168: 1080x1920 23.2ms, 1 drone
# Speed: 47.8ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 169: 1080x1920 23.4ms, 1 drone
# Speed: 52.4ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 170: 1080x1920 23.3ms, 1 drone
# Speed: 48.2ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 171: 1080x1920 23.1ms, 1 drone
# Speed: 50.5ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 172: 1080x1920 23.6ms, 1 drone
# Speed: 48.9ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 173: 1080x1920 23.4ms, 1 drone
# Speed: 47.4ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 174: 1080x1920 24.1ms, 1 drone
# Speed: 47.6ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 175: 1080x1920 24.0ms, 1 drone
# Speed: 50.3ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 176: 1080x1920 23.8ms, 1 drone
# Speed: 50.2ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 177: 1080x1920 24.2ms, 1 drone
# Speed: 47.9ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 178: 1080x1920 24.0ms, 1 drone
# Speed: 51.1ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 179: 1080x1920 24.5ms, 1 drone
# Speed: 49.5ms track, 24.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 180: 1080x1920 23.0ms, 1 drone
# Speed: 48.8ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 181: 1080x1920 23.6ms, 1 drone
# Speed: 51.3ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 182: 1080x1920 23.6ms, 1 drone
# Speed: 50.3ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 183: 1080x1920 24.0ms, 1 drone
# Speed: 47.7ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 184: 1080x1920 23.7ms, 1 drone
# Speed: 49.8ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 185: 1080x1920 23.5ms, 1 drone
# Speed: 50.0ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 186: 1080x1920 24.0ms, 1 drone
# Speed: 47.8ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 187: 1080x1920 24.0ms, 1 drone
# Speed: 48.3ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 188: 1080x1920 23.8ms, 1 drone
# Speed: 50.3ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 189: 1080x1920 24.2ms, 1 drone
# Speed: 51.9ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 190: 1080x1920 24.1ms, 1 drone
# Speed: 48.9ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 191: 1080x1920 23.9ms, 1 drone
# Speed: 49.3ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 192: 1080x1920 24.0ms, 1 drone
# Speed: 49.5ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 193: 1080x1920 24.1ms, 1 drone
# Speed: 48.4ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 194: 1080x1920 23.9ms, 1 drone
# Speed: 48.6ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 195: 1080x1920 23.9ms, 1 drone
# Speed: 48.2ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 196: 1080x1920 24.5ms, 1 drone
# Speed: 48.7ms track, 24.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 197: 1080x1920 24.1ms, 1 drone
# Speed: 50.1ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 198: 1080x1920 24.1ms, 1 drone
# Speed: 49.0ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 199: 1080x1920 24.1ms, 1 drone
# Speed: 49.6ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 200: 1080x1920 23.1ms, 1 drone
# Speed: 50.2ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 201: 1080x1920 23.9ms, 1 drone
# Speed: 49.8ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 202: 1080x1920 24.0ms, 1 drone
# Speed: 48.4ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 203: 1080x1920 24.2ms, 1 drone
# Speed: 49.0ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 204: 1080x1920 23.6ms, 1 drone
# Speed: 50.0ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 205: 1080x1920 23.9ms, 1 drone
# Speed: 49.5ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 206: 1080x1920 24.1ms, 1 drone
# Speed: 47.9ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 207: 1080x1920 22.9ms, 1 drone
# Speed: 50.8ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 208: 1080x1920 23.2ms, 1 drone
# Speed: 49.2ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 209: 1080x1920 23.4ms, 1 drone
# Speed: 48.4ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 210: 1080x1920 24.1ms, 1 drone
# Speed: 49.0ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 211: 1080x1920 23.8ms, 1 drone
# Speed: 49.0ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 212: 1080x1920 23.9ms, 1 drone
# Speed: 49.0ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 213: 1080x1920 22.8ms, 1 drone
# Speed: 49.8ms track, 22.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 214: 1080x1920 22.6ms, 1 drone
# Speed: 49.5ms track, 22.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 215: 1080x1920 23.3ms, 1 drone
# Speed: 48.6ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 216: 1080x1920 23.9ms, 1 drone
# Speed: 47.8ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 217: 1080x1920 23.5ms, 1 drone
# Speed: 48.5ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 218: 1080x1920 23.4ms, 1 drone
# Speed: 49.9ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 219: 1080x1920 23.0ms, 1 drone
# Speed: 50.9ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 220: 1080x1920 23.8ms, 1 drone
# Speed: 49.1ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 221: 1080x1920 23.0ms, 1 drone
# Speed: 49.6ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 222: 1080x1920 23.5ms, 1 drone
# Speed: 48.7ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 223: 1080x1920 23.6ms, 1 drone
# Speed: 48.4ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 224: 1080x1920 23.0ms, 1 drone
# Speed: 49.1ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 225: 1080x1920 23.5ms, 1 drone
# Speed: 48.5ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 226: 1080x1920 23.6ms, 1 drone
# Speed: 48.2ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 227: 1080x1920 24.2ms, 1 drone
# Speed: 50.5ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 228: 1080x1920 24.3ms, 1 drone
# Speed: 50.5ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 229: 1080x1920 23.1ms, 1 drone
# Speed: 51.0ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 230: 1080x1920 23.2ms, 1 drone
# Speed: 50.2ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 231: 1080x1920 23.5ms, 1 drone
# Speed: 47.8ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 232: 1080x1920 23.6ms, 1 drone
# Speed: 48.1ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 233: 1080x1920 22.8ms, 1 drone
# Speed: 48.4ms track, 22.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 234: 1080x1920 23.5ms, 1 drone
# Speed: 48.1ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 235: 1080x1920 23.3ms, 1 drone
# Speed: 48.8ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 236: 1080x1920 23.2ms, 1 drone
# Speed: 49.2ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 237: 1080x1920 23.0ms, 1 drone
# Speed: 49.2ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 238: 1080x1920 22.9ms, 1 drone
# Speed: 50.7ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 239: 1080x1920 23.1ms, 1 drone
# Speed: 49.3ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 240: 1080x1920 23.0ms, 1 drone
# Speed: 48.0ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 241: 1080x1920 22.4ms, 1 drone
# Speed: 50.4ms track, 22.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 242: 1080x1920 22.1ms, 1 drone
# Speed: 49.6ms track, 22.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 243: 1080x1920 22.6ms, 1 drone
# Speed: 49.5ms track, 22.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 244: 1080x1920 23.4ms, 1 drone
# Speed: 48.3ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 245: 1080x1920 23.3ms, 1 drone
# Speed: 49.8ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 246: 1080x1920 22.6ms, 1 drone
# Speed: 50.6ms track, 22.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 247: 1080x1920 23.2ms, 1 drone
# Speed: 50.0ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 248: 1080x1920 22.5ms, 1 drone
# Speed: 49.8ms track, 22.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 249: 1080x1920 23.5ms, 1 drone
# Speed: 49.2ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 250: 1080x1920 23.0ms, 1 drone
# Speed: 48.5ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 251: 1080x1920 22.9ms, 1 drone
# Speed: 48.7ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 252: 1080x1920 23.3ms, 1 drone
# Speed: 49.0ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 253: 1080x1920 23.0ms, 1 drone
# Speed: 50.2ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 254: 1080x1920 23.4ms, 1 drone
# Speed: 49.6ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 255: 1080x1920 23.4ms, 1 drone
# Speed: 48.0ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 256: 1080x1920 23.6ms, 1 drone
# Speed: 48.8ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 257: 1080x1920 23.7ms, 1 drone
# Speed: 51.2ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 258: 1080x1920 23.5ms, 1 drone
# Speed: 50.3ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 259: 1080x1920 23.4ms, 1 drone
# Speed: 48.7ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 260: 1080x1920 23.2ms, 1 drone
# Speed: 49.1ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 261: 1080x1920 23.6ms, 1 drone
# Speed: 49.2ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 262: 1080x1920 23.9ms, 1 drone
# Speed: 49.7ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 263: 1080x1920 23.8ms, 1 drone
# Speed: 49.1ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 264: 1080x1920 24.2ms, 1 drone
# Speed: 48.6ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 265: 1080x1920 24.3ms, 1 drone
# Speed: 48.2ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 266: 1080x1920 24.2ms, 1 drone
# Speed: 49.2ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 267: 1080x1920 24.2ms, 1 drone
# Speed: 51.0ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 268: 1080x1920 68.5ms, 2 drone
# Speed: 49.1ms track, 68.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 269: 1080x1920 69.6ms, 2 drone
# Speed: 49.1ms track, 69.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 270: 1080x1920 68.8ms, 2 drone
# Speed: 51.0ms track, 68.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 271: 1080x1920 68.1ms, 2 drone
# Speed: 49.1ms track, 68.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 272: 1080x1920 67.3ms, 2 drone
# Speed: 51.6ms track, 67.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 273: 1080x1920 59.9ms, 2 drone
# Speed: 50.4ms track, 59.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 274: 1080x1920 23.8ms, 1 drone
# Speed: 48.3ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 275: 1080x1920 23.6ms, 1 drone
# Speed: 47.7ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 276: 1080x1920 23.6ms, 1 drone
# Speed: 54.3ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 277: 1080x1920 23.7ms, 1 drone
# Speed: 50.5ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 278: 1080x1920 23.9ms, 1 drone
# Speed: 48.5ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 279: 1080x1920 24.1ms, 1 drone
# Speed: 49.0ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 280: 1080x1920 24.4ms, 1 drone
# Speed: 49.0ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 281: 1080x1920 24.3ms, 1 drone
# Speed: 48.2ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 282: 1080x1920 24.3ms, 1 drone
# Speed: 48.3ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 283: 1080x1920 24.0ms, 1 drone
# Speed: 49.3ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 284: 1080x1920 23.9ms, 1 drone
# Speed: 48.8ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 285: 1080x1920 23.7ms, 1 drone
# Speed: 47.8ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 286: 1080x1920 23.9ms, 1 drone
# Speed: 49.0ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 287: 1080x1920 24.1ms, 1 drone
# Speed: 50.0ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 288: 1080x1920 24.1ms, 1 drone
# Speed: 47.9ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 289: 1080x1920 24.0ms, 1 drone
# Speed: 48.4ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 290: 1080x1920 23.7ms, 1 drone
# Speed: 49.4ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 291: 1080x1920 23.6ms, 1 drone
# Speed: 48.8ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 292: 1080x1920 24.2ms, 1 drone
# Speed: 49.1ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 293: 1080x1920 24.5ms, 1 drone
# Speed: 48.5ms track, 24.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 294: 1080x1920 24.6ms, 1 drone
# Speed: 49.0ms track, 24.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 295: 1080x1920 23.9ms, 1 drone
# Speed: 48.0ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 296: 1080x1920 23.7ms, 1 drone
# Speed: 46.6ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 297: 1080x1920 56.4ms, 2 drone
# Speed: 49.5ms track, 56.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 298: 1080x1920 56.5ms, 2 drone
# Speed: 52.9ms track, 56.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 299: 1080x1920 23.4ms, 1 drone
# Speed: 48.6ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 300: 1080x1920 23.4ms, 1 drone
# Speed: 47.1ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 301: 1080x1920 23.7ms, 1 drone
# Speed: 48.9ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 302: 1080x1920 23.7ms, 1 drone
# Speed: 48.7ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 303: 1080x1920 24.1ms, 1 drone
# Speed: 48.6ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 304: 1080x1920 23.5ms, 1 drone
# Speed: 48.0ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 305: 1080x1920 24.0ms, 1 drone
# Speed: 48.6ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 306: 1080x1920 24.2ms, 1 drone
# Speed: 47.8ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 307: 1080x1920 24.3ms, 1 drone
# Speed: 49.0ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 308: 1080x1920 24.6ms, 1 drone
# Speed: 49.4ms track, 24.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 309: 1080x1920 23.9ms, 1 drone
# Speed: 47.7ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 310: 1080x1920 24.4ms, 1 drone
# Speed: 52.0ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 311: 1080x1920 24.1ms, 1 drone
# Speed: 49.5ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 312: 1080x1920 24.1ms, 1 drone
# Speed: 48.9ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 313: 1080x1920 23.8ms, 1 drone
# Speed: 47.6ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 314: 1080x1920 24.1ms, 1 drone
# Speed: 49.1ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 315: 1080x1920 24.4ms, 1 drone
# Speed: 48.4ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 316: 1080x1920 23.4ms, 1 drone
# Speed: 48.5ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 317: 1080x1920 23.1ms, 1 drone
# Speed: 48.1ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 318: 1080x1920 23.3ms, 1 drone
# Speed: 50.1ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 319: 1080x1920 23.6ms, 1 drone
# Speed: 48.8ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 320: 1080x1920 23.2ms, 1 drone
# Speed: 48.6ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 321: 1080x1920 23.5ms, 1 drone
# Speed: 48.0ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 322: 1080x1920 23.7ms, 1 drone
# Speed: 51.4ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 323: 1080x1920 23.2ms, 1 drone
# Speed: 48.9ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 324: 1080x1920 22.9ms, 1 drone
# Speed: 48.8ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 325: 1080x1920 23.0ms, 1 drone
# Speed: 48.2ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 326: 1080x1920 23.3ms, 1 drone
# Speed: 47.4ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 327: 1080x1920 23.7ms, 1 drone
# Speed: 47.8ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 328: 1080x1920 23.9ms, 1 drone
# Speed: 48.3ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 329: 1080x1920 24.1ms, 1 drone
# Speed: 48.8ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 330: 1080x1920 24.1ms, 1 drone
# Speed: 48.9ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 331: 1080x1920 23.9ms, 1 drone
# Speed: 47.8ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 332: 1080x1920 23.3ms, 1 drone
# Speed: 48.1ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 333: 1080x1920 23.1ms, 1 drone
# Speed: 48.8ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 334: 1080x1920 23.8ms, 1 drone
# Speed: 54.8ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 335: 1080x1920 23.4ms, 1 drone
# Speed: 47.0ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 336: 1080x1920 23.8ms, 1 drone
# Speed: 47.3ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 337: 1080x1920 24.1ms, 1 drone
# Speed: 49.7ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 338: 1080x1920 24.2ms, 1 drone
# Speed: 51.1ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 339: 1080x1920 23.7ms, 1 drone
# Speed: 53.7ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 340: 1080x1920 58.4ms, 2 drone
# Speed: 48.4ms track, 58.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 341: 1080x1920 24.1ms, 1 drone
# Speed: 48.2ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 342: 1080x1920 23.7ms, 1 drone
# Speed: 46.9ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 343: 1080x1920 24.1ms, 1 drone
# Speed: 47.9ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 344: 1080x1920 57.0ms, 2 drone
# Speed: 46.8ms track, 57.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 345: 1080x1920 23.6ms, 1 drone
# Speed: 46.9ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 346: 1080x1920 23.9ms, 1 drone
# Speed: 50.1ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 347: 1080x1920 23.8ms, 1 drone
# Speed: 47.4ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 348: 1080x1920 23.3ms, 1 drone
# Speed: 46.6ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 349: 1080x1920 23.5ms, 1 drone
# Speed: 46.5ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 350: 1080x1920 23.6ms, 1 drone
# Speed: 48.2ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 351: 1080x1920 23.6ms, 1 drone
# Speed: 48.3ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 352: 1080x1920 23.5ms, 1 drone
# Speed: 47.0ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 353: 1080x1920 23.3ms, 1 drone
# Speed: 46.7ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 354: 1080x1920 23.5ms, 1 drone
# Speed: 48.2ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 355: 1080x1920 23.5ms, 1 drone
# Speed: 47.1ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 356: 1080x1920 23.5ms, 1 drone
# Speed: 47.7ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 357: 1080x1920 23.4ms, 1 drone
# Speed: 48.7ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 358: 1080x1920 23.2ms, 1 drone
# Speed: 50.3ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 359: 1080x1920 23.2ms, 1 drone
# Speed: 47.3ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 360: 1080x1920 23.2ms, 1 drone
# Speed: 45.8ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 361: 1080x1920 23.0ms, 1 drone
# Speed: 47.3ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 362: 1080x1920 23.3ms, 1 drone
# Speed: 46.8ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 363: 1080x1920 23.4ms, 1 drone
# Speed: 48.5ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 364: 1080x1920 23.6ms, 1 drone
# Speed: 48.3ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 365: 1080x1920 23.4ms, 1 drone
# Speed: 46.9ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 366: 1080x1920 23.7ms, 1 drone
# Speed: 48.3ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 367: 1080x1920 23.7ms, 1 drone
# Speed: 47.1ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 368: 1080x1920 23.8ms, 1 drone
# Speed: 47.7ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 369: 1080x1920 23.8ms, 1 drone
# Speed: 49.5ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 370: 1080x1920 23.6ms, 1 drone
# Speed: 52.1ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 371: 1080x1920 23.4ms, 1 drone
# Speed: 48.0ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 372: 1080x1920 23.3ms, 1 drone
# Speed: 47.2ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 373: 1080x1920 23.3ms, 1 drone
# Speed: 46.7ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 374: 1080x1920 23.5ms, 1 drone
# Speed: 48.2ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 375: 1080x1920 24.0ms, 1 drone
# Speed: 46.6ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 376: 1080x1920 24.1ms, 1 drone
# Speed: 49.5ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 377: 1080x1920 23.8ms, 1 drone
# Speed: 48.0ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 378: 1080x1920 23.9ms, 1 drone
# Speed: 47.7ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 379: 1080x1920 23.9ms, 1 drone
# Speed: 47.8ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 380: 1080x1920 24.1ms, 1 drone
# Speed: 48.2ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 381: 1080x1920 24.4ms, 1 drone
# Speed: 49.3ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 382: 1080x1920 24.3ms, 1 drone
# Speed: 51.3ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 383: 1080x1920 24.1ms, 1 drone
# Speed: 48.3ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 384: 1080x1920 24.0ms, 1 drone
# Speed: 47.4ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 385: 1080x1920 24.2ms, 1 drone
# Speed: 48.5ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 386: 1080x1920 24.3ms, 1 drone
# Speed: 47.5ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 387: 1080x1920 24.4ms, 1 drone
# Speed: 48.5ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 388: 1080x1920 24.2ms, 1 drone
# Speed: 48.2ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 389: 1080x1920 24.1ms, 1 drone
# Speed: 48.5ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 390: 1080x1920 24.1ms, 1 drone
# Speed: 47.5ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 391: 1080x1920 24.1ms, 1 drone
# Speed: 46.3ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 392: 1080x1920 24.0ms, 1 drone
# Speed: 48.1ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 393: 1080x1920 23.7ms, 1 drone
# Speed: 47.9ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 394: 1080x1920 24.0ms, 1 drone
# Speed: 53.7ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 395: 1080x1920 23.6ms, 1 drone
# Speed: 49.0ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 396: 1080x1920 23.7ms, 1 drone
# Speed: 48.6ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 397: 1080x1920 23.6ms, 1 drone
# Speed: 46.8ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 398: 1080x1920 23.8ms, 1 drone
# Speed: 47.7ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 399: 1080x1920 23.7ms, 1 drone
# Speed: 48.2ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 400: 1080x1920 23.6ms, 1 drone
# Speed: 47.7ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 401: 1080x1920 23.6ms, 1 drone
# Speed: 46.5ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 402: 1080x1920 23.7ms, 1 drone
# Speed: 47.5ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 403: 1080x1920 23.8ms, 1 drone
# Speed: 48.4ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 404: 1080x1920 24.1ms, 1 drone
# Speed: 48.4ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 405: 1080x1920 24.5ms, 1 drone
# Speed: 49.6ms track, 24.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 406: 1080x1920 24.0ms, 1 drone
# Speed: 50.9ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 407: 1080x1920 23.9ms, 1 drone
# Speed: 48.8ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 408: 1080x1920 23.6ms, 1 drone
# Speed: 49.5ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 409: 1080x1920 23.5ms, 1 drone
# Speed: 48.6ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 410: 1080x1920 23.5ms, 1 drone
# Speed: 47.6ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 411: 1080x1920 24.0ms, 1 drone
# Speed: 49.0ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 412: 1080x1920 24.0ms, 1 drone
# Speed: 48.1ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 413: 1080x1920 24.4ms, 1 drone
# Speed: 47.7ms track, 24.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 414: 1080x1920 24.0ms, 1 drone
# Speed: 46.8ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 415: 1080x1920 23.6ms, 1 drone
# Speed: 46.5ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 416: 1080x1920 23.4ms, 1 drone
# Speed: 49.6ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 417: 1080x1920 23.5ms, 1 drone
# Speed: 48.9ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 418: 1080x1920 23.7ms, 1 drone
# Speed: 47.5ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 419: 1080x1920 24.1ms, 1 drone
# Speed: 48.4ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 420: 1080x1920 23.7ms, 1 drone
# Speed: 48.3ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 421: 1080x1920 23.6ms, 1 drone
# Speed: 46.7ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 422: 1080x1920 23.3ms, 1 drone
# Speed: 48.2ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 423: 1080x1920 23.5ms, 1 drone
# Speed: 49.2ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 424: 1080x1920 23.7ms, 1 drone
# Speed: 48.7ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 425: 1080x1920 23.8ms, 1 drone
# Speed: 47.1ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 426: 1080x1920 23.9ms, 1 drone
# Speed: 47.5ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 427: 1080x1920 23.8ms, 1 drone
# Speed: 48.4ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 428: 1080x1920 23.9ms, 1 drone
# Speed: 48.1ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 429: 1080x1920 24.2ms, 1 drone
# Speed: 48.7ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 430: 1080x1920 23.6ms, 1 drone
# Speed: 48.9ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 431: 1080x1920 23.7ms, 1 drone
# Speed: 48.2ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 432: 1080x1920 23.1ms, 1 drone
# Speed: 47.2ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 433: 1080x1920 23.3ms, 1 drone
# Speed: 46.8ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 434: 1080x1920 23.6ms, 1 drone
# Speed: 46.4ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 435: 1080x1920 23.5ms, 1 drone
# Speed: 47.6ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 436: 1080x1920 23.8ms, 1 drone
# Speed: 48.3ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 437: 1080x1920 23.8ms, 1 drone
# Speed: 47.6ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 438: 1080x1920 23.5ms, 1 drone
# Speed: 48.3ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 439: 1080x1920 23.3ms, 1 drone
# Speed: 49.1ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 440: 1080x1920 23.9ms, 1 drone
# Speed: 48.4ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 441: 1080x1920 23.3ms, 1 drone
# Speed: 49.1ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 442: 1080x1920 23.9ms, 1 drone
# Speed: 48.3ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 443: 1080x1920 24.2ms, 1 drone
# Speed: 47.4ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 444: 1080x1920 23.8ms, 1 drone
# Speed: 48.0ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 445: 1080x1920 24.1ms, 1 drone
# Speed: 47.2ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 446: 1080x1920 23.8ms, 1 drone
# Speed: 47.4ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 447: 1080x1920 23.9ms, 1 drone
# Speed: 50.0ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 448: 1080x1920 23.9ms, 1 drone
# Speed: 47.7ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 449: 1080x1920 23.6ms, 1 drone
# Speed: 48.3ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 450: 1080x1920 23.3ms, 1 drone
# Speed: 46.7ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 451: 1080x1920 23.6ms, 1 drone
# Speed: 49.7ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 452: 1080x1920 23.6ms, 1 drone
# Speed: 50.0ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 453: 1080x1920 24.2ms, 1 drone
# Speed: 48.8ms track, 24.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 454: 1080x1920 23.7ms, 1 drone
# Speed: 47.4ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 455: 1080x1920 23.1ms, 1 drone
# Speed: 47.5ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 456: 1080x1920 23.4ms, 1 drone
# Speed: 47.9ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 457: 1080x1920 23.7ms, 1 drone
# Speed: 47.0ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 458: 1080x1920 24.1ms, 1 drone
# Speed: 48.7ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 459: 1080x1920 23.7ms, 1 drone
# Speed: 51.2ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 460: 1080x1920 23.4ms, 1 drone
# Speed: 47.8ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 461: 1080x1920 23.4ms, 1 drone
# Speed: 49.0ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 462: 1080x1920 23.5ms, 1 drone
# Speed: 47.3ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 463: 1080x1920 23.8ms, 1 drone
# Speed: 47.5ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 464: 1080x1920 23.6ms, 1 drone
# Speed: 48.7ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 465: 1080x1920 23.5ms, 1 drone
# Speed: 48.7ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 466: 1080x1920 23.6ms, 1 drone
# Speed: 48.8ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 467: 1080x1920 23.8ms, 1 drone
# Speed: 48.0ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 468: 1080x1920 25.1ms, 1 drone
# Speed: 53.2ms track, 25.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 469: 1080x1920 25.0ms, 1 drone
# Speed: 53.1ms track, 25.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 470: 1080x1920 23.8ms, 1 drone
# Speed: 50.5ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 471: 1080x1920 23.5ms, 1 drone
# Speed: 51.3ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 472: 1080x1920 23.6ms, 1 drone
# Speed: 48.6ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 473: 1080x1920 23.4ms, 1 drone
# Speed: 48.5ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 474: 1080x1920 23.1ms, 1 drone
# Speed: 47.8ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 475: 1080x1920 23.7ms, 1 drone
# Speed: 47.7ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 476: 1080x1920 23.7ms, 1 drone
# Speed: 51.5ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 477: 1080x1920 23.7ms, 1 drone
# Speed: 48.2ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 478: 1080x1920 23.6ms, 1 drone
# Speed: 48.3ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 479: 1080x1920 23.1ms, 1 drone
# Speed: 47.6ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 480: 1080x1920 22.5ms, 1 drone
# Speed: 52.7ms track, 22.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 481: 1080x1920 22.9ms, 1 drone
# Speed: 51.1ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 482: 1080x1920 23.0ms, 1 drone
# Speed: 47.2ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 483: 1080x1920 23.0ms, 1 drone
# Speed: 51.2ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 484: 1080x1920 23.1ms, 1 drone
# Speed: 48.1ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 485: 1080x1920 22.9ms, 1 drone
# Speed: 48.4ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 486: 1080x1920 22.8ms, 1 drone
# Speed: 46.9ms track, 22.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 487: 1080x1920 23.2ms, 1 drone
# Speed: 47.7ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 488: 1080x1920 23.1ms, 1 drone
# Speed: 53.6ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 489: 1080x1920 23.3ms, 1 drone
# Speed: 47.9ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 490: 1080x1920 23.1ms, 1 drone
# Speed: 47.7ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 491: 1080x1920 23.1ms, 1 drone
# Speed: 49.0ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 492: 1080x1920 23.1ms, 1 drone
# Speed: 51.8ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 493: 1080x1920 22.7ms, 1 drone
# Speed: 51.5ms track, 22.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 494: 1080x1920 23.4ms, 1 drone
# Speed: 48.2ms track, 23.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 495: 1080x1920 23.1ms, 1 drone
# Speed: 51.4ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 496: 1080x1920 23.3ms, 1 drone
# Speed: 48.8ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 497: 1080x1920 23.7ms, 1 drone
# Speed: 51.5ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 498: 1080x1920 23.1ms, 1 drone
# Speed: 48.5ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 499: 1080x1920 22.7ms, 1 drone
# Speed: 47.5ms track, 22.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 500: 1080x1920 23.0ms, 1 drone
# Speed: 52.6ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 501: 1080x1920 22.4ms, 1 drone
# Speed: 49.6ms track, 22.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 502: 1080x1920 22.6ms, 1 drone
# Speed: 47.8ms track, 22.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 503: 1080x1920 23.0ms, 1 drone
# Speed: 49.0ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 504: 1080x1920 23.1ms, 1 drone
# Speed: 52.3ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 505: 1080x1920 23.2ms, 1 drone
# Speed: 51.6ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 506: 1080x1920 23.6ms, 1 drone
# Speed: 48.7ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 507: 1080x1920 23.2ms, 1 drone
# Speed: 52.2ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 508: 1080x1920 23.2ms, 1 drone
# Speed: 50.2ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 509: 1080x1920 23.5ms, 1 drone
# Speed: 49.4ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 510: 1080x1920 24.1ms, 1 drone
# Speed: 47.7ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 511: 1080x1920 23.5ms, 1 drone
# Speed: 47.5ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 512: 1080x1920 23.9ms, 1 drone
# Speed: 52.4ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 513: 1080x1920 24.0ms, 1 drone
# Speed: 48.3ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 514: 1080x1920 23.6ms, 1 drone
# Speed: 47.0ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 515: 1080x1920 24.1ms, 1 drone
# Speed: 47.7ms track, 24.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 516: 1080x1920 23.9ms, 1 drone
# Speed: 51.8ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 517: 1080x1920 24.3ms, 1 drone
# Speed: 52.9ms track, 24.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 518: 1080x1920 24.0ms, 1 drone
# Speed: 49.4ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 519: 1080x1920 23.9ms, 1 drone
# Speed: 51.9ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 520: 1080x1920 23.9ms, 1 drone
# Speed: 48.4ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 521: 1080x1920 23.8ms, 1 drone
# Speed: 47.6ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 522: 1080x1920 23.6ms, 1 drone
# Speed: 48.6ms track, 23.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 523: 1080x1920 23.0ms, 1 drone
# Speed: 48.7ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 524: 1080x1920 23.8ms, 1 drone
# Speed: 53.5ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 525: 1080x1920 23.7ms, 1 drone
# Speed: 49.8ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 526: 1080x1920 23.9ms, 1 drone
# Speed: 47.1ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 527: 1080x1920 23.8ms, 1 drone
# Speed: 49.0ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 528: 1080x1920 23.7ms, 1 drone
# Speed: 53.1ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 529: 1080x1920 24.0ms, 1 drone
# Speed: 51.8ms track, 24.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 530: 1080x1920 23.7ms, 1 drone
# Speed: 48.8ms track, 23.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 531: 1080x1920 23.2ms, 1 drone
# Speed: 52.2ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 532: 1080x1920 23.9ms, 1 drone
# Speed: 48.7ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 533: 1080x1920 23.0ms, 1 drone
# Speed: 49.0ms track, 23.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 534: 1080x1920 23.8ms, 1 drone
# Speed: 49.3ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 535: 1080x1920 23.9ms, 1 drone
# Speed: 49.2ms track, 23.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 536: 1080x1920 23.2ms, 1 drone
# Speed: 54.5ms track, 23.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 537: 1080x1920 22.9ms, 1 drone
# Speed: 49.1ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 538: 1080x1920 23.8ms, 1 drone
# Speed: 48.7ms track, 23.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 539: 1080x1920 23.3ms, 1 drone
# Speed: 49.0ms track, 23.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 540: 1080x1920 22.9ms, 1 drone
# Speed: 48.2ms track, 22.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 541: 1080x1920 23.5ms, 1 drone
# Speed: 49.0ms track, 23.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 542: 1080x1920 22.7ms, 1 drone
# Speed: 48.5ms track, 22.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 543: 1080x1920 23.1ms, 1 drone
# Speed: 49.4ms track, 23.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 544: 1080x1920 30.2ms, 2 drone
# Speed: 49.2ms track, 30.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 545: 1080x1920 30.2ms, 2 drone
# Speed: 48.9ms track, 30.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 546: 1080x1920 29.6ms, 2 drone
# Speed: 48.7ms track, 29.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 547: 1080x1920 28.6ms, 2 drone
# Speed: 47.8ms track, 28.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 548: 1080x1920 21.9ms, 1 drone
# Speed: 48.8ms track, 21.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 549: 1080x1920 29.3ms, 2 drone
# Speed: 50.8ms track, 29.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 550: 1080x1920 29.3ms, 2 drone
# Speed: 49.7ms track, 29.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 551: 1080x1920 29.3ms, 2 drone
# Speed: 48.8ms track, 29.3ms solution per image at shape (1, 3, 1080, 1920)
#
# Video processing complete. Saved to /content/my_outputs/tracking_output/heatmap_output.mp4

# %%
print(dir(results))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'available_slots', 'classwise_count', 'email_sent', 'filled_slots', 'in_count', 'out_count', 'pixels_distance', 'plot_im', 'queue_count', 'region_counts', 'speed', 'speed_dict', 'total_crop_objects', 'total_tracks', 'workout_angle', 'workout_count', 'workout_stage']

# %%
from IPython.display import Video
Video("/content/heatmap_output.mp4", embed=True)

# %% [markdown]
# **Key points:**
#
# * **Heatmap Generation**: Aggregates detection activity to visualize drone movement density.
# * **Colormap**: `cv2.COLORMAP_JET` highlights intensity variations.
# * **Lightweight Model**: `/content/runs/detect/train/weights/best.pt` used for rapid heatmap generation.
#
# This dual approach—tracking and heatmap visualization—provided both temporal tracking accuracy and spatial activity insights, making it valuable for surveillance, airspace monitoring, and security analysis.
#
#
# *   Video source: [@ninosouza](https://www.pexels.com/@ninosouza/)
# *   Video link: [pexels](https://www.pexels.com/video/an-airborne-drone-machine-8459631/)

# %% [markdown]
# ## **5. Save the Weights and Configuration File**

# %%
# model.export(format='onnx')

# %%
# !mv /content/my_outputs /content/runs/detect/

# %%
# !zip -r '/content/results.zip' '/content/runs/detect/'
# Out:
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/results.png (deflated 8%)
#   adding: content/runs/detect/train/args.yaml (deflated 52%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 14%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 12%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 19%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 13%)
#   adding: content/runs/detect/train/train_batch1410.jpg (deflated 16%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 21%)
#   adding: content/runs/detect/train/BoxP_curve.png (deflated 17%)
#   adding: content/runs/detect/train/BoxF1_curve.png (deflated 16%)
#   adding: content/runs/detect/train/train_batch1409.jpg (deflated 18%)
#   adding: content/runs/detect/train/results.csv (deflated 59%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 15%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 37%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 14%)
#   adding: content/runs/detect/train/BoxR_curve.png (deflated 16%)
#   adding: content/runs/detect/train/labels.jpg (deflated 30%)
#   adding: content/runs/detect/train/BoxPR_curve.png (deflated 22%)
#   adding: content/runs/detect/train/train_batch1408.jpg (deflated 24%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 13%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 15%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 36%)
#   adding: content/runs/detect/my_outputs/ (stored 0%)
#   adding: content/runs/detect/my_outputs/tracking_output/ (stored 0%)
#   adding: content/runs/detect/my_outputs/tracking_output/pexels-joseph-redfield-8459631 (1080p).avi (deflated 4%)
#   adding: content/runs/detect/my_outputs/tracking_output/heatmap_output.mp4 (deflated 6%)

# %%
files.download('/content/data.yaml')

# %%
files.download('/content/results.zip')

# %%
# !mv /content/results.zip /content/gdrive/MyDrive/

# %% [markdown]
# ## **Results and Discussion**
#
# We present comprehensive results of our drone detection model's performance on both the training and testing datasets. The evaluation metrics include precision, recall, and F1-score, which are standard measures to assess the model's detection accuracy.

# %% [markdown]
# ## **Conclusion**
#
# Our research addresses the critical need for reliable drone detection systems by proposing a comprehensive dataset and a state-of-the-art detection model using the YOLOv11x architecture. The availability of our curated dataset and the promising performance of our model offer valuable contributions to the field of drone detection. The outcomes of this study can pave the way for enhanced security measures and privacy protection in areas where drones pose potential risks.

# %% [markdown]
# ## **Contact Me**
# <p>If you have something to say to me please contact me:</p>
#
# <ul>
#   <li>Mail address: doguilmak@gmail.com</li>
# </ul>

# %%
from datetime import datetime
print(f"Changes have been made to the project on {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Changes have been made to the project on 2025-08-09 13:11:09
